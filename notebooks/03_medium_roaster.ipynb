# %% [markdown]
# # 03 - Medium Roaster
#
# This notebook implements our balanced CV critique model.
#
# ## Characteristics
# - Professional but honest tone & direct feedback without sugarcoating
# - Points out obvious issues clearly while maintains professionalism
# - Using medium temperature (0.6-0.8) for more varied and candid responses
#
# ---

# %%
import pandas as pd
import json
from pathlib import Path
from datetime import datetime
import sys
sys.path.append('..')
import google.generativeai as genai

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
# Out:
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# /Users/hannokuegler/Library/CloudStorage/OneDrive-WUWien/SBWL/Data Science/4_LLM/roast_my_cv/roast_my_cv/.venv1/lib/python3.9/site-packages/google/api_core/_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.6) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/hannokuegler/Library/CloudStorage/OneDrive-WUWien/SBWL/Data Science/4_LLM/roast_my_cv/roast_my_cv/.venv1/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Setup

# %%
# Load API key from config.py
import sys
sys.path.append('..')
from config import GEMINI_API_KEY
genai.configure(api_key=GEMINI_API_KEY)
print("API key loaded from config.py")
# Out:
# API key loaded from config.py

# %% [markdown]
# ## Load Data and Helper Functions

# %%
# Load dataset
df = pd.read_csv('../data/resume_data.csv')

# Load test CV indices
with open('../data/test_cv_indices.json', 'r') as f:
    test_data = json.load(f)
    test_cv_indices = test_data['indices']

print(f"Loaded {len(df)} resumes")
print(f"Test CVs: {test_cv_indices}")
# Out:
# Loaded 9544 resumes
# Test CVs: [0, 1]

# %%
# CV formatting function
def format_cv_for_llm(resume_row):
    """
    Format a resume row into a readable text for LLM processing.
    """
    cv_text = []
    
    if pd.notna(resume_row.get('career_objective')):
        cv_text.append(f"CAREER OBJECTIVE:\n{resume_row['career_objective']}")
    
    if pd.notna(resume_row.get('skills')):
        cv_text.append(f"\nSKILLS:\n{resume_row['skills']}")
    
    education_parts = []
    if pd.notna(resume_row.get('educational_institution_name')):
        education_parts.append(f"Institution: {resume_row['educational_institution_name']}")
    if pd.notna(resume_row.get('degree_names')):
        education_parts.append(f"Degree: {resume_row['degree_names']}")
    if pd.notna(resume_row.get('major_field_of_studies')):
        education_parts.append(f"Major: {resume_row['major_field_of_studies']}")
    if pd.notna(resume_row.get('passing_years')):
        education_parts.append(f"Year: {resume_row['passing_years']}")
    
    if education_parts:
        cv_text.append(f"\nEDUCATION:\n" + "\n".join(education_parts))
    
    work_parts = []
    if pd.notna(resume_row.get('professional_company_names')):
        work_parts.append(f"Company: {resume_row['professional_company_names']}")
    if pd.notna(resume_row.get('positions')):
        work_parts.append(f"Position: {resume_row['positions']}")
    if pd.notna(resume_row.get('start_dates')):
        work_parts.append(f"Period: {resume_row['start_dates']}")
        if pd.notna(resume_row.get('end_dates')):
            work_parts.append(f" to {resume_row['end_dates']}")
    if pd.notna(resume_row.get('responsibilities')):
        work_parts.append(f"Responsibilities:\n{resume_row['responsibilities']}")
    
    if work_parts:
        cv_text.append(f"\nWORK EXPERIENCE:\n" + "\n".join(work_parts))
    
    if pd.notna(resume_row.get('languages')):
        cv_text.append(f"\nLANGUAGES:\n{resume_row['languages']}")
    
    if pd.notna(resume_row.get('certification_skills')):
        cv_text.append(f"\nCERTIFICATIONS:\n{resume_row['certification_skills']}")
    
    return "\n".join(cv_text)

# %% [markdown]
# ## Medium Roaster Prompt Design

# %%
MEDIUM_SYSTEM_PROMPT = """You are an experienced hiring manager who provides direct, honest CV feedback.

Your approach:
1. Be direct and honest - no sugarcoating
2. Point out obvious flaws and red flags
3. Call out generic buzzwords and filler content
4. Be professional but don't hold back the truth
5. Focus on what actually matters to employers

Keep your feedback:
- Brutally honest but professional
- Direct about weaknesses
- Critical of vague or generic content
- Focused on real-world hiring standards

Structure your response:
 FIRST IMPRESSION: What stands out (good or bad)
 MAJOR ISSUES: Glaring problems that need fixing
 CONCERNS: Things that raise questions
 WHAT WORKS: Brief acknowledgment of strengths
 BOTTOM LINE: Final verdict and priority fixes
"""

def create_medium_prompt(cv_text):
    """Create a medium roasting prompt."""
    return f"""Review this CV with honest, direct feedback. Don't hold back on pointing out issues:

{cv_text}

Provide your honest assessment following the structure in the system prompt."""

# %% [markdown]
# ## Temperature Tuning Experiments
#
# Let's test different temperatures for more varied and candid responses.

# %%
def roast_cv(cv_text, temperature=0.7, model_name="gemini-2.0-flash"):
    """
    Generate CV critique using Gemini.
    
    Args:
        cv_text: Formatted CV text
        temperature: Controls randomness (0.0-1.0)
        model_name: Gemini model to use
    
    Returns:
        str: Generated critique
    """
    model = genai.GenerativeModel(
        model_name=model_name,
        generation_config=genai.GenerationConfig(
            temperature=temperature,
            top_p=0.95,
            top_k=40,
            max_output_tokens=1024,
        )
    )
    
    full_prompt = f"{MEDIUM_SYSTEM_PROMPT}\n\n{create_medium_prompt(cv_text)}"
    
    response = model.generate_content(full_prompt)
    return response.text

# Test with first CV
test_cv = format_cv_for_llm(df.iloc[test_cv_indices[0]])
print("Test CV:")
print("="*80)
print(test_cv[:500] + "...")
print("="*80)
# Out:
# Test CV:
# ================================================================================
# CAREER OBJECTIVE:
# Big data analytics working and database warehouse manager with robust experience in handling all kinds of data. I have also used multiple cloud infrastructure services and am well acquainted with them. Currently in search of role that offers more of development.
#
# SKILLS:
# ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapreduce', 'Spark', 'Java', 'Machine Learning', 'Cloud', 'Hdfs', 'YARN', 'Core Java', 'Data Science', 'C++', 'Data Structures', 'DBMS', 'RDBMS', 'Informatica', 'Talend...
# ================================================================================

# %% [markdown]
# ### Experiment 1: Medium Temperature (0.6)
# More varied but still controlled

# %%
print(" Temperature: 0.6 (Controlled Variety)")
print("="*80)
result_temp_06 = roast_cv(test_cv, temperature=0.6)
print(result_temp_06)
print("\n" + "="*80)
# Out:
#  Temperature: 0.6 (Controlled Variety)
# ================================================================================
# Okay, here's my brutally honest assessment of this CV:
#
# **FIRST IMPRESSION:** This CV screams "generic and underdeveloped." It's a list of keywords followed by vague responsibilities. It lacks substance and doesn't showcase any real achievements. The formatting is also questionable, especially the "to ['Till Date']" under work experience.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective is terrible:** It's a rambling, buzzword-filled sentence that says nothing concrete. "Robust experience in handling all kinds of data" is meaningless. What kind of data? What kind of experience? And the shift to wanting "more of development" is confusing. Is this a data analyst or a developer? This needs a complete rewrite or, better yet, deletion. Objectives are outdated.
# *   **Skills Section is just a keyword dump:** Listing skills without demonstrating them is useless. Anyone can copy and paste a list of technologies. Where's the evidence of proficiency? What projects have you used these skills on? How have you applied them to solve problems?
# *   **Work Experience is shockingly vague:** "Technical Support," "Troubleshooting," "Collaboration," "Documentation," "System Monitoring," "Software Deployment," "Training & Mentorship," "Industry Trends," "Field Visits" – these are generic responsibilities that could apply to almost any job. What specific problems did you solve? What impact did you have? Where are the quantifiable results? Using bullet points with action verbs and specific accomplishments is essential. "Coca-COla" is also misspelt.
# *   **Education is underdeveloped:** A B.Tech from ASET is fine, but where's the GPA? Relevant coursework? Capstone projects? Any academic achievements?
#
# **CONCERNS:**
#
# *   **"Till Date" in the work experience:** While common, it's a bit lazy. Update it with the actual end date, even if it's recent.
# *   **Electronics background for a Big Data Analyst role:** While not a deal-breaker, it raises questions. How did you transition into data analytics? What specific skills from your electronics background are relevant? This needs to be addressed in the work experience descriptions.
# *   **Inconsistent formatting:** The "to ['Till Date']" issue highlights a lack of attention to detail. This makes me question the overall quality of your work.
#
# **WHAT WORKS:**
#
# *   The skills section, while needing context, at least shows awareness of relevant technologies.
# *   The Coca-Cola name carries some weight, but it's wasted with the weak descriptions.
#
# **BOTTOM LINE:**
#
# This CV is a mess. It's generic, vague, and fails to demonstrate any real value. **Priority #1 is to rewrite the work experience section with specific accomplishments and quantifiable results.** Then, either rewrite the career objective into a compelling summary or remove it entirely. Provide context for your skills and highlight projects where you've used them. Proofread carefully to eliminate typos. Until these changes are made, this CV is unlikely to get you past the initial screening. You need to show, not tell, that you're a competent data analyst.
#
#
# ================================================================================

# %% [markdown]
# ### Experiment 2: Medium-High Temperature (0.7)
# Good balance of creativity and directness

# %%
print(" Temperature: 0.7 (Balanced)")
print("="*80)
result_temp_07 = roast_cv(test_cv, temperature=0.7)
print(result_temp_07)
print("\n" + "="*80)
# Out:
#  Temperature: 0.7 (Balanced)
# ================================================================================
# Okay, here's my brutally honest assessment of this CV:
#
# **FIRST IMPRESSION:** This looks like a very junior profile trying to sound more experienced than they are. The career objective is weak, the skills section is a massive keyword dump, and the work experience is shockingly vague.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective is Terrible:** "Big data analytics working and database warehouse manager" is not a coherent objective. It reads like you threw a bunch of buzzwords together. And the last sentence "Currently in search of role that offers more of development" is poorly written and tells me you're already dissatisfied with your current role. This needs a complete rewrite, focusing on a specific target role and highlighting what *you* bring to the table, not what you *want*.
# *   **Skills Section is a Keyword Vomit:** Listing every buzzword under the sun doesn't make you an expert. It makes you look like you're trying to game the system. You need to *demonstrate* these skills in your experience, not just list them. And the sheer volume of skills listed suggests a lack of depth in any of them.
# *   **Work Experience is Pathetic:** "Technical Support, Troubleshooting, Collaboration..." This is generic filler. Every job involves these things. What *specifically* did you do? What problems did you solve? What technologies did you use? How did you impact Coca-Cola's business? This section is a black hole of missing information. The responsibilities listed could apply to literally any IT role.
# *   **Inconsistent Formatting:** The education section lists each field as a separate element in a list. Is this an attempt to make it seem longer? This looks amateurish.
# *   **"Till Date" is Lazy:** Always specify an end date, even if it's just "Present". "Till Date" makes it seem like you couldn't be bothered.
#
# **CONCERNS:**
#
# *   **Electronics Degree, Big Data Analyst:** This raises questions about your career path. How did you transition from electronics to big data? Did you take additional courses, certifications, or projects? This needs to be addressed proactively, not left to the hiring manager's imagination.
# *   **Coca-Cola, Big Data Analyst:** While Coca-Cola is a well-known company, what kind of big data challenges does a beverage company face? You need to contextualize your experience and demonstrate the relevance of your work to other industries.
# *   **Lack of Quantifiable Results:** There are zero metrics in your work experience. Did you improve data processing speed? Reduce costs? Increase efficiency? Numbers are crucial for demonstrating your impact.
#
# **WHAT WORKS:**
#
# *   ...Honestly, not much. The fact that you have *some* work experience is a plus, but it's currently presented in a way that's almost useless.
#
# **BOTTOM LINE:**
#
# This CV is a mess. It screams "junior candidate trying to fake it 'til they make it." You need to completely rewrite the career objective, drastically reduce and refine the skills section, and *completely* overhaul the work experience to focus on accomplishments and quantifiable results. You also need to address the career transition from electronics to data analytics.
#
# **Priority Fixes:**
#
# 1.  **Rewrite Work Experience:** This is the absolute most important thing. Focus on achievements, technologies used, and quantifiable results.
# 2.  **Refine Skills Section:** Be honest about your expertise. Focus on the skills you *actually* use regularly and can demonstrate.
# 3.  **Rewrite Career Objective:** Make it specific, targeted, and focused on what you offer.
# 4.  **Address Career Transition:** Explain how you moved from electronics to big data.
#
# Until you fix these issues, this CV is likely to be immediately rejected. Good luck, you'll need it.
#
#
# ================================================================================

# %% [markdown]
# ### Experiment 3: High Temperature (0.8)
# More creative and varied critiques

# %%
print(" Temperature: 0.8 (More Creative)")
print("="*80)
result_temp_08 = roast_cv(test_cv, temperature=0.8)
print(result_temp_08)
print("\n" + "="*80)
# Out:
#  Temperature: 0.8 (More Creative)
# ================================================================================
# Okay, let's dissect this CV. Prepare for some tough love.
#
# **FIRST IMPRESSION:** This reads like a template someone filled in halfway and then gave up. It's incredibly generic, lacks substance, and immediately raises red flags.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective:** This is terrible. "Big data analytics working and database warehouse manager..." is grammatically awkward and doesn't say *anything* about what you bring to the table or what kind of development role you're seeking. It reads like you just mashed together keywords. The mention of cloud infrastructure is vague and meaningless without context. This needs a complete rewrite to focus on your target role and quantifiable achievements.
# *   **Skills Section:** This is just a laundry list of buzzwords. Listing technologies without demonstrating proficiency or context is useless. Anyone can copy and paste a list of skills; hiring managers want to see *how* you've used them to solve problems and deliver results. The mix of skills is also a bit all over the place (C++, Java, Informatica, Azure...etc). It needs to be tailored to a specific role and backed up by experience.
# *   **Work Experience - Coca-Cola:** This is the biggest red flag. "Technical Support, Troubleshooting, Collaboration, Documentation, System Monitoring, Software Deployment, Training & Mentorship, Industry Trends, Field Visits" are vague *responsibilities* that could apply to almost any job. Where are the accomplishments? Where is the impact? What specific projects did you work on? What were the results? Saying you were a "Big Data Analyst" and then listing generic support tasks is a huge disconnect. This section needs a complete overhaul with specific, quantifiable achievements. Using action verbs and the STAR method is a must. Also, why is the company name misspelled?
# *   **Education:** Fine, but the lack of GPA or relevant coursework hurts.
#
# **CONCERNS:**
#
# *   **"Till Date":** While acceptable, it's always better to put a specific end month/year to show you are attentive to details.
# *   **Electronics Background:** An electronics degree isn't inherently bad, but it raises questions about your transition into data analytics. You need to explicitly address how you gained the necessary skills and experience.
# *   **Lack of Projects/Portfolio:** For someone seeking a development role, the absence of personal projects or a portfolio is a serious disadvantage.
#
# **WHAT WORKS:**
#
# *   The formatting is clean and simple.
#
# **BOTTOM LINE:**
#
# This CV is a major problem. It's generic, lacks substance, and doesn't demonstrate any real value.
#
# **Priority Fixes:**
#
# 1.  **Completely rewrite the career objective:** Focus on your target role and what you bring to the table.
# 2.  **Overhaul the Coca-Cola experience:** Provide specific accomplishments, quantifiable results, and concrete examples of your contributions. This is your biggest opportunity to showcase your skills.
# 3.  **Tailor the skills section:** Focus on the skills relevant to your target role and provide context for how you've used them.
# 4.  **Address your educational background:** Explain how you transitioned into data analytics.
# 5.  **Consider adding a projects/portfolio section:** This is crucial for demonstrating your development skills.
#
# Without these changes, this CV will likely be rejected immediately. Good luck.
#
#
# ================================================================================

# %% [markdown]
# ## Select Optimal Temperature
#
# **Recommended: 0.7 for medium roasting** - provides good balance of:
# - Direct, honest feedback
# - Varied critique points
# - Professional but candid tone

# %%
# Set optimal temperature
OPTIMAL_TEMPERATURE = 0.7

print(f" Selected optimal temperature: {OPTIMAL_TEMPERATURE}")
# Out:
#  Selected optimal temperature: 0.7

# %% [markdown]
# ## Generate Results for Test CVs

# %%
# Create results directory
results_dir = Path('../results/medium_roaster')
results_dir.mkdir(parents=True, exist_ok=True)

# Process each test CV
results = []

for idx in test_cv_indices:
    print(f"\n{'='*80}")
    print(f"Processing CV #{idx}")
    print(f"{'='*80}\n")
    
    # Format CV
    cv_text = format_cv_for_llm(df.iloc[idx])
    
    # Generate critique
    critique = roast_cv(cv_text, temperature=OPTIMAL_TEMPERATURE)
    
    # Save result
    result = {
        'cv_index': idx,
        'model': 'medium_roaster',
        'temperature': OPTIMAL_TEMPERATURE,
        'timestamp': datetime.now().isoformat(),
        'cv_text': cv_text,
        'critique': critique
    }
    
    results.append(result)
    
    # Save to file
    output_file = results_dir / f"cv_{idx}_medium.json"
    with open(output_file, 'w') as f:
        json.dump(result, f, indent=2)
    
    # Display result
    print(f" Original CV:")
    print("-"*80)
    print(cv_text)
    print(f"\n Medium Critique:")
    print("-"*80)
    print(critique)
    print(f"\n Saved to: {output_file}")
    print(f"\n{'='*80}\n")

print(f"\n Generated {len(results)} medium critiques")
# Out:
# ================================================================================
# Processing CV #0
# ================================================================================
#
#  Original CV:
# --------------------------------------------------------------------------------
# CAREER OBJECTIVE:
# Big data analytics working and database warehouse manager with robust experience in handling all kinds of data. I have also used multiple cloud infrastructure services and am well acquainted with them. Currently in search of role that offers more of development.
#
# SKILLS:
# ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapreduce', 'Spark', 'Java', 'Machine Learning', 'Cloud', 'Hdfs', 'YARN', 'Core Java', 'Data Science', 'C++', 'Data Structures', 'DBMS', 'RDBMS', 'Informatica', 'Talend', 'Amazon Redshift', 'Microsoft Azure']
#
# EDUCATION:
# Institution: ['The Amity School of Engineering & Technology (ASET), Noida']
# Degree: ['B.Tech']
# Major: ['Electronics']
# Year: ['2019']
#
# WORK EXPERIENCE:
# Company: ['Coca-COla']
# Position: ['Big Data Analyst']
# Period: ['Nov 2019']
#  to ['Till Date']
# Responsibilities:
# Technical Support
# Troubleshooting
# Collaboration
# Documentation
# System Monitoring
# Software Deployment
# Training & Mentorship
# Industry Trends
# Field Visits
#
#
#
#
#
#
#  Medium Critique:
# --------------------------------------------------------------------------------
# Okay, here's my brutally honest assessment of this CV. Buckle up.
#
# **FIRST IMPRESSION:**
#
# This CV screams "generic and underbaked." It looks like someone threw a bunch of keywords at a wall and hoped they'd stick. The formatting is terrible, and the content lacks any real substance.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective:** This is terrible. It's vague, poorly written, and tells me nothing about what you actually *offer* an employer. "In search of role that offers more of development" is a grammatical nightmare and says you're unhappy where you are. Ditch this entirely. Objectives are outdated.
# *   **Skills Section:** Just a list of keywords. Meaningless without context. Anyone can list skills; you need to *prove* you have them. Listing C++ and Data Structures alongside Big Data tools is odd and suggests you're trying to cover too much ground. Also, the inconsistent capitalization is irritating (e.g., 'Mapreduce' vs 'Amazon Redshift').
# *   **Work Experience:** This is the biggest problem. "Coca-COla" (typo alert!) and "Big Data Analyst" sounds impressive, but the responsibilities listed are incredibly generic and could apply to *any* IT role. "Technical Support," "Troubleshooting," "Collaboration," "Documentation," "System Monitoring," "Software Deployment," "Training & Mentorship," "Industry Trends," "Field Visits" – these are all filler. Where's the *big data analysis*? Where are the *results*? What specific tools did you use and what business problems did you solve? This section is a black hole of information.
# *   **Education:** Okay, but the lack of a GPA or any relevant coursework is a missed opportunity.
#
# **CONCERNS:**
#
# *   **"Till Date":** This is lazy. Update your CV every time you achieve something new. Saying "Till Date" implies you haven't done anything significant recently.
# *   **Electronics Background:** You have a B.Tech in Electronics, but you're applying for data roles. This isn't necessarily a deal-breaker, but you need to *explicitly* connect your education to your data skills. How did you transition? What relevant projects did you undertake?
# *   **Informatica and Talend:** Listing both Informatica and Talend raises an eyebrow. While knowing both is possible, it might suggest a lack of deep expertise in either. Be prepared to answer questions about why you know both.
#
# **WHAT WORKS:**
#
# *   The list of skills provides a starting point. You have identified some relevant technologies.
# *   The work experience at Coca-Cola *could* be a strength, but as it is right now, it's a weakness.
#
# **BOTTOM LINE:**
#
# This CV, as it stands, will likely get you rejected. It's generic, lacks substance, and doesn't effectively showcase your skills or experience.
#
# **Priority Fixes:**
#
# 1.  **Completely rewrite the Work Experience section.** Focus on quantifiable achievements and specific projects. Use the STAR method (Situation, Task, Action, Result) to demonstrate your impact.
# 2.  **Remove the Career Objective.** It's doing you no favors.
# 3.  **Tailor your Skills section.** Remove irrelevant skills (like C++ if you're not actively using it) and provide context for the remaining ones.
# 4.  **Proofread everything!** Fix typos and ensure consistent formatting.
#
# You need to transform this CV from a list of buzzwords into a compelling narrative that demonstrates your value as a Big Data Analyst. Good luck – you have a lot of work to do.
#
#
#  Saved to: ../results/medium_roaster/cv_0_medium.json
#
# ================================================================================
#
#
# ================================================================================
# Processing CV #1
# ================================================================================
#
#  Original CV:
# --------------------------------------------------------------------------------
# CAREER OBJECTIVE:
# Fresher looking to join as a data analyst and junior data scientist. Experienced in creating meaningful data dashboards and evaluation models.
#
# SKILLS:
# ['Data Analysis', 'Data Analytics', 'Business Analysis', 'R', 'SAS', 'PowerBi', 'Tableau', 'Data Visualization', 'Business Analytics', 'Machine Learning']
#
# EDUCATION:
# Institution: ['Delhi University - Hansraj College', 'Delhi University - Hansraj College']
# Degree: ['B.Sc (Maths)', 'M.Sc (Science) (Statistics)']
# Major: ['Mathematics', 'Statistics']
# Year: ['2015', '2018']
#
# WORK EXPERIENCE:
# Company: ['BIB Consultancy']
# Position: ['Business Analyst']
# Period: ['Sep 2019']
#  to ['Till Date']
# Responsibilities:
# Machine Learning Leadership
# Cross-Functional Collaboration
# Strategy Development
# ML/NLP Infrastructure
# Prototype Transformation
# ML System Design
# Algorithm Research
# Application Development
# Dataset Selection
# ML Testing
# Statistical Analysis
# R&D in ML/NLP
# Text Representation
# Data Pipeline Design
# Statistical Data Analysis
# Model Training
# Team Collaboration
# Research Reporting
# Algorithm Analysis
#
#  Medium Critique:
# --------------------------------------------------------------------------------
# Okay, here's my brutally honest take on this CV:
#
# **FIRST IMPRESSION:** This looks like a keyword dump disguised as a CV. It screams of someone trying to game the system without actually having the substance to back it up. The "Career Objective" is weak and the "Responsibilities" section reads like a laundry list of buzzwords.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective is Generic and Useless:** "Fresher looking to join..." No hiring manager cares what you're *looking* to do. They care about what you *can* do. This needs to be replaced with a concise summary of your quantifiable achievements and skills that directly align with the roles you're targeting.
# *   **Skills Section is a Keyword Salad:** Listing skills like this is meaningless without demonstration. You're just shouting buzzwords. Anyone can write "Machine Learning" – prove you know it. This section needs to be integrated into your experience, showing *how* you used these skills. Also, "Data Analysis" and "Data Analytics" and "Business Analytics" are all redundant. Choose the most accurate and impactful term.
# *   **Experience Section is a Buzzword Nightmare:** "Machine Learning Leadership," "Strategy Development," "ML/NLP Infrastructure" - as a Business Analyst with less than 5 years of experience, I *highly* doubt you led ML infrastructure development. This entire section reads like you copy-pasted a job description for a senior data scientist. The sheer volume of responsibilities is unbelievable for a single person, especially at the stated experience level.
# *   **Inconsistent Dates:** You graduated in 2018 and started this role in 2019. What were you doing in that gap year? This needs to be addressed.
# *   **Format and Presentation:** This format is terrible. No one wants to read skills listed like a Python list. It's lazy and unprofessional.
#
# **CONCERNS:**
#
# *   **"Till Date" is a Red Flag:** While it's not inherently bad, it raises questions. Why are you leaving? What are you looking for? Be prepared to answer these.
# *   **BIB Consultancy:** I'd be Googling this company immediately. Is it a real company? Does it have a legitimate online presence? The inflated responsibilities make me suspicious.
# *   **B.Sc. (Maths) and M.Sc. (Science) (Statistics):** The "Science" part of the Masters degree is unnecessary. Just list it as M.Sc. Statistics.
#
# **WHAT WORKS:**
#
# *   **Educational Background is Relevant:** The degrees in Maths and Statistics are good foundation for data roles.
#
# **BOTTOM LINE:**
#
# This CV is a mess and would likely be rejected immediately by most recruiters. The biggest problem is the unbelievable experience section, which reeks of exaggeration or outright fabrication.
#
# **Priority Fixes:**
#
# 1.  **Completely rewrite the experience section.** Focus on 2-3 *specific* projects where you used data analysis skills. Quantify your achievements with metrics (e.g., "Increased sales by 15% by implementing a new customer segmentation model"). Be honest and realistic about your contributions.
# 2.  **Remove the Career Objective and replace it with a strong professional summary.** Highlight your key skills and quantifiable achievements.
# 3.  **Integrate skills into your experience section.** Instead of just listing them, show how you used them in your projects.
# 4.  **Address the gap between graduation and your first job.**
# 5.  **Reformat the entire CV.** Use a professional template that is easy to read and visually appealing.
#
# You need to rebuild this CV from the ground up. Honesty and quantifiable achievements are key. Stop trying to be someone you're not and focus on showcasing your actual skills and experience in a clear and compelling way.
#
#
#  Saved to: ../results/medium_roaster/cv_1_medium.json
#
# ================================================================================
#
#
#  Generated 2 medium critiques

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# 1.  Direct, honest CV critique prompt design
# 2.  Temperature tuning experiments (0.6, 0.7, 0.8)
# 3.  Selection of optimal temperature for candid feedback
# 4.  Generation of critiques for test CVs
# 5.  Saving results for comparison
#
# ---
#
# ## Next: 04_brutal_roaster.ipynb
# Savage, no-holds-barred roasting with humor.
