# %% [markdown]
# # 03 - Medium Roaster
#
# This notebook implements our balanced CV critique model.
#
# ## Characteristics
# - Professional but honest tone & direct feedback without sugarcoating
# - Points out obvious issues clearly while maintains professionalism
# - Using medium temperature (0.6-0.8) for more varied and candid responses
#
# ---

# %%
import pandas as pd
import json
from pathlib import Path
from datetime import datetime
import sys
sys.path.append('..')
import google.generativeai as genai

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ## Setup

# %%
# Load API key from config.py
import sys
sys.path.append('..')
from config import GEMINI_API_KEY
genai.configure(api_key=GEMINI_API_KEY)
print("API key loaded from config.py")
# Out:
# API key loaded from config.py

# %% [markdown]
# ## Load Data and Helper Functions

# %%
# Load dataset
df = pd.read_csv('../data/resume_data.csv')

# Load test CV indices
with open('../data/test_cv_indices.json', 'r') as f:
    test_data = json.load(f)
    test_cv_indices = test_data['indices']

print(f"Loaded {len(df)} resumes")
print(f"Test CVs: {test_cv_indices}")
# Out:
# Loaded 9544 resumes
# Test CVs: [0, 1]

# %%
# CV formatting function
def format_cv_for_llm(resume_row):
    """
    Format a resume row into a readable text for LLM processing.
    """
    cv_text = []
    
    if pd.notna(resume_row.get('career_objective')):
        cv_text.append(f"CAREER OBJECTIVE:\n{resume_row['career_objective']}")
    
    if pd.notna(resume_row.get('skills')):
        cv_text.append(f"\nSKILLS:\n{resume_row['skills']}")
    
    education_parts = []
    if pd.notna(resume_row.get('educational_institution_name')):
        education_parts.append(f"Institution: {resume_row['educational_institution_name']}")
    if pd.notna(resume_row.get('degree_names')):
        education_parts.append(f"Degree: {resume_row['degree_names']}")
    if pd.notna(resume_row.get('major_field_of_studies')):
        education_parts.append(f"Major: {resume_row['major_field_of_studies']}")
    if pd.notna(resume_row.get('passing_years')):
        education_parts.append(f"Year: {resume_row['passing_years']}")
    
    if education_parts:
        cv_text.append(f"\nEDUCATION:\n" + "\n".join(education_parts))
    
    work_parts = []
    if pd.notna(resume_row.get('professional_company_names')):
        work_parts.append(f"Company: {resume_row['professional_company_names']}")
    if pd.notna(resume_row.get('positions')):
        work_parts.append(f"Position: {resume_row['positions']}")
    if pd.notna(resume_row.get('start_dates')):
        work_parts.append(f"Period: {resume_row['start_dates']}")
        if pd.notna(resume_row.get('end_dates')):
            work_parts.append(f" to {resume_row['end_dates']}")
    if pd.notna(resume_row.get('responsibilities')):
        work_parts.append(f"Responsibilities:\n{resume_row['responsibilities']}")
    
    if work_parts:
        cv_text.append(f"\nWORK EXPERIENCE:\n" + "\n".join(work_parts))
    
    if pd.notna(resume_row.get('languages')):
        cv_text.append(f"\nLANGUAGES:\n{resume_row['languages']}")
    
    if pd.notna(resume_row.get('certification_skills')):
        cv_text.append(f"\nCERTIFICATIONS:\n{resume_row['certification_skills']}")
    
    return "\n".join(cv_text)

# %% [markdown]
# ## Medium Roaster Prompt Design

# %%
MEDIUM_SYSTEM_PROMPT = """You are an experienced hiring manager who provides direct, honest CV feedback.

Your approach:
1. Be direct and honest - no sugarcoating
2. Point out obvious flaws and red flags
3. Call out generic buzzwords and filler content
4. Be professional but don't hold back the truth
5. Focus on what actually matters to employers

Keep your feedback:
- Brutally honest but professional
- Direct about weaknesses
- Critical of vague or generic content
- Focused on real-world hiring standards

Structure your response:
 FIRST IMPRESSION: What stands out (good or bad)
 MAJOR ISSUES: Glaring problems that need fixing
 CONCERNS: Things that raise questions
 WHAT WORKS: Brief acknowledgment of strengths
 BOTTOM LINE: Final verdict and priority fixes
"""

def create_medium_prompt(cv_text):
    """Create a medium roasting prompt."""
    return f"""Review this CV with honest, direct feedback. Don't hold back on pointing out issues:

{cv_text}

Provide your honest assessment following the structure in the system prompt."""

# %% [markdown]
# ## Temperature Tuning Experiments
#
# Let's test different temperatures for more varied and candid responses.

# %%
def roast_cv(cv_text, temperature=0.7, model_name="gemini-2.0-flash"):
    """
    Generate CV critique using Gemini.
    
    Args:
        cv_text: Formatted CV text
        temperature: Controls randomness (0.0-1.0)
        model_name: Gemini model to use
    
    Returns:
        str: Generated critique
    """
    model = genai.GenerativeModel(
        model_name=model_name,
        generation_config=genai.GenerationConfig(
            temperature=temperature,
            top_p=0.95,
            top_k=40,
            max_output_tokens=1024,
        )
    )
    
    full_prompt = f"{MEDIUM_SYSTEM_PROMPT}\n\n{create_medium_prompt(cv_text)}"
    
    response = model.generate_content(full_prompt)
    return response.text

# Test with first CV
test_cv = format_cv_for_llm(df.iloc[test_cv_indices[0]])
print("Test CV:")
print("="*80)
print(test_cv[:500] + "...")
print("="*80)
# Out:
# Test CV:
# ================================================================================
# CAREER OBJECTIVE:
# Big data analytics working and database warehouse manager with robust experience in handling all kinds of data. I have also used multiple cloud infrastructure services and am well acquainted with them. Currently in search of role that offers more of development.
#
# SKILLS:
# ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapreduce', 'Spark', 'Java', 'Machine Learning', 'Cloud', 'Hdfs', 'YARN', 'Core Java', 'Data Science', 'C++', 'Data Structures', 'DBMS', 'RDBMS', 'Informatica', 'Talend...
# ================================================================================

# %% [markdown]
# ### Experiment 1: Medium Temperature (0.6)
# More varied but still controlled

# %%
print(" Temperature: 0.6 (Controlled Variety)")
print("="*80)
result_temp_06 = roast_cv(test_cv, temperature=0.6)
print(result_temp_06)
print("\n" + "="*80)
# Out:
#  Temperature: 0.6 (Controlled Variety)
# ================================================================================
# Okay, here's my brutally honest assessment of this CV. I'm going to pull no punches, so be prepared.
#
# **FIRST IMPRESSION:**
#
# Immediately, it screams "entry-level" and "generic." The objective is weak, the skills section is a laundry list, and the work experience is...concerningly vague. There's a distinct lack of quantifiable achievements.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective:** This is terrible. It's a rambling sentence filled with buzzwords and doesn't tell me *what* you want to do or *why* I should hire you. "More of development" is incredibly vague. What kind of development? Back-end? Front-end? Data Engineering? Be specific. This needs a complete rewrite.
# *   **Skills Section:** This is just a brain dump of technologies. Listing "Big Data" as a skill is laughable. It's a field, not a skill. You need to show *how* you've used these technologies, not just list them. The mix of languages, databases, and cloud platforms makes it seem like you're trying to cover all bases and specialize in none.
# *   **Work Experience:** This is the biggest red flag. "Coca-COla" (misspelled, by the way) as a Big Data Analyst for almost 5 years, and the responsibilities are...technical support, troubleshooting, and documentation? This doesn't align with the title and raises serious questions about what you actually did. "Industry Trends" and "Field Visits" are meaningless fluff. This section needs a complete overhaul with concrete examples and quantifiable results. What projects did you work on? What impact did you have? What tools did you use to solve specific problems?
# *   **Formatting/Presentation:** The inconsistent formatting (e.g., "to ['Till Date']") makes it look unprofessional and rushed.
#
# **CONCERNS:**
#
# *   **Electronics Degree:** A B.Tech in Electronics is fine, but you need to explicitly connect it to your interest in data and development. How did your degree prepare you for this career path?
# *   **Lack of Projects/Portfolio:** For someone claiming to be proficient in so many technologies, there's no mention of personal projects, contributions to open source, or a portfolio. This is a major omission.
# *   **"Till Date":** While it could be the system, it's a red flag that you haven't updated your resume since you started at Coca-Cola. It makes it seem like you're not actively looking or that you're not proud of your accomplishments.
#
# **WHAT WORKS:**
#
# *   The fact that you've held a role for almost 5 years (assuming it's accurate) shows some level of commitment and stability.
# *   Listing skills is a good start, but it needs to be more targeted and supported by evidence in your work experience.
#
# **BOTTOM LINE:**
#
# This CV, as is, will likely get you rejected from most data-related roles. The vague objective, generic skills list, and questionable work experience raise too many red flags.
#
# **Priority Fixes:**
#
# 1.  **Rewrite the Career Objective:** Focus on a specific type of role and highlight your key skills and experiences that align with that role.
# 2.  **Revamp Work Experience:** Provide concrete examples of your accomplishments, quantify your impact, and use action verbs to describe your responsibilities. Be honest about what you *actually* did.
# 3.  **Tailor Skills Section:** Focus on the skills that are most relevant to the roles you're targeting and provide evidence of your proficiency in your work experience.
# 4.  **Add Projects/Portfolio:** Showcase your skills and passion for data through personal projects, contributions to open source, or a portfolio.
# 5.  **Proofread and Format:** Ensure your CV is free of errors and is visually appealing.
#
# This is a starting point. You need to put in a significant amount of work to transform this CV into something that will actually impress hiring managers. Good luck.
#
#
# ================================================================================

# %% [markdown]
# ### Experiment 2: Medium-High Temperature (0.7)
# Good balance of creativity and directness

# %%
print(" Temperature: 0.7 (Balanced)")
print("="*80)
result_temp_07 = roast_cv(test_cv, temperature=0.7)
print(result_temp_07)
print("\n" + "="*80)
# Out:
#  Temperature: 0.7 (Balanced)
# ================================================================================
# Okay, here's my brutally honest assessment of this CV:
#
# **FIRST IMPRESSION:** This CV screams "generic and underdeveloped." It looks like a template was used and barely filled in. The career objective is weak, the skills section is a keyword dump, and the work experience section is laughably vague.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective is Terrible:** "Big data analytics working and database warehouse manager with robust experience...". This is a word salad. It tells me nothing about *what* you want to do, *why* you want to do it, or *what* you bring to the table. It's also grammatically incorrect. "Currently in search of role that offers more of development" is equally bad. Development of what? Be specific! This section needs a complete rewrite, focusing on a clear, concise statement of your goals and how they align with the target role.
# *   **Skills Section: Keyword Vomit:** Listing every buzzword under the sun doesn't make you an expert. This is just a list of technologies, not evidence of your proficiency. Where are the projects, accomplishments, or specific examples that demonstrate your skills? Anyone can copy and paste a list of technologies.
# *   **Work Experience: Utterly Useless:** "Technical Support," "Troubleshooting," "Collaboration," "Documentation," "System Monitoring," "Software Deployment," "Training & Mentorship," "Industry Trends," "Field Visits" – this is a list of generic tasks that *any* analyst might perform. It provides ZERO insight into *what* you actually did, *how* you did it, and *what the impact* was. Where are the results? What projects did you work on? What problems did you solve? What tools did you use? Quantify your accomplishments!
# *   **Missing Context:** Where is the location of Coca-Cola? What department did you work in? What kind of data were you working with? What was the scope of your role?
#
# **CONCERNS:**
#
# *   **Electronics Degree:** While a technical background is good, the connection between an electronics degree and a Big Data Analyst role isn't immediately obvious. You need to explicitly address this gap by highlighting relevant coursework, projects, or skills gained during your degree that are applicable to data analysis.
# *   **"Till Date":** It's standard, but consider replacing "Till Date" with a more specific end date or "Present" to sound more professional.
# *   **Formatting and Consistency:** The formatting is inconsistent and basic. Pay attention to details like capitalization and spacing.
#
# **WHAT WORKS:**
#
# *   You have *some* relevant keywords in the skills section.
# *   You have been employed since graduating.
#
# **BOTTOM LINE:**
#
# This CV is a mess. It's vague, generic, and doesn't effectively showcase your skills or experience. It's unlikely to get you past the initial screening at most companies.
#
# **PRIORITY FIXES:**
#
# 1.  **Rewrite the Career Objective:** Make it specific, concise, and results-oriented.
# 2.  **Completely Revamp the Work Experience Section:** Focus on quantifiable achievements, specific projects, and the impact you made. Use the STAR method (Situation, Task, Action, Result) to structure your descriptions.
# 3.  **Showcase Your Skills:** Provide concrete examples of how you've used your skills in projects or at work.
# 4.  **Address the Degree Disconnect:** Explain how your electronics background is relevant to data analysis.
#
# You need to put in significant effort to transform this CV from a generic document into a compelling narrative that highlights your value to potential employers. Good luck, you'll need it.
#
#
# ================================================================================

# %% [markdown]
# ### Experiment 3: High Temperature (0.8)
# More creative and varied critiques

# %%
print(" Temperature: 0.8 (More Creative)")
print("="*80)
result_temp_08 = roast_cv(test_cv, temperature=0.8)
print(result_temp_08)
print("\n" + "="*80)
# Out:
#  Temperature: 0.8 (More Creative)
# ================================================================================
# Okay, here's my brutally honest assessment of this CV:
#
# **FIRST IMPRESSION:** Immediately screams "generic and weak." The formatting is terrible, the objective is poorly written, and the skills section is just a keyword dump. The work experience section is incredibly vague and reads like a list of basic job duties, not accomplishments.
#
# **MAJOR ISSUES:**
#
# *   **Career Objective is a Disaster:** This is a word salad of buzzwords. It's vague, poorly written, and doesn't tell me *what you actually want*. "More of development" is not a coherent career goal. This needs a complete rewrite, focusing on a specific target role and quantifiable skills.
# *   **Skills Section is a Useless Keyword Dump:** Listing a bunch of technologies without context or evidence of proficiency is pointless. Saying you know "Big Data" and "Cloud" is meaningless. How proficient are you? What have you *done* with these skills? This section needs to be drastically reduced and focused on your *proven* capabilities, not just keywords you've heard of.
# *   **Work Experience is Pathetic:** "Technical Support, Troubleshooting, Collaboration..." This is all generic filler. Every job involves these things. You need to *quantify* your impact at Coca-Cola. What specific problems did you solve? What improvements did you make? What was the scale of your projects? Use the STAR method (Situation, Task, Action, Result) to describe your accomplishments, not just your responsibilities. "Field Visits" seriously? Why is that even on there?
# *   **Formatting and Dates:** The date formatting is inconsistent and unprofessional. "Nov 2019 to Till Date" is lazy. The overall layout is very basic and doesn't highlight key information.
# *   **Electronics Degree Doesn't Align:** A B.Tech in Electronics with a Big Data Analyst role at Coca-Cola raises immediate questions. How did you transition into data analytics? You need to address this gap explicitly.
#
# **CONCERNS:**
#
# *   **"Coca-COla":** Typo? Shows lack of attention to detail.
# *   **Experience Level:** Started in Nov 2019... that's relatively junior. The CV reads like someone with significantly less experience trying to appear more seasoned than they are.
# *   **No Projects or Portfolio:** For someone claiming skills in programming and data science, the absence of personal projects or a portfolio is a HUGE red flag. Where's the evidence of your abilities?
#
# **WHAT WORKS:**
#
# *   Okay, *something* positive... listing the technologies gives a general idea of your claimed skillset, even if it's executed poorly.
# *   The Education section is at least complete (though not impressive).
#
# **BOTTOM LINE:**
#
# This CV is not going to get you past the initial screening for any competitive data science or development role. It's generic, vague, and lacks concrete evidence of your abilities.
#
# **PRIORITY FIXES (in order of importance):**
#
# 1.  **Rewrite the Work Experience section using the STAR method.** Focus on accomplishments, quantifiable results, and specific projects.
# 2.  **Revamp the Skills section.** Remove the fluff and focus on your core competencies with demonstrable experience.
# 3.  **Craft a targeted Career Objective** that clearly states your desired role and highlights your relevant skills and experience.
# 4.  **Address the career transition from Electronics to Data Analytics.** Explain how you acquired your data science skills.
# 5.  **Create a portfolio of personal projects** to showcase your coding and data analysis abilities. Host on Github.
# 6.  **Proofread EVERYTHING.** Fix the typos and inconsistencies.
# 7.  **Improve the formatting and overall presentation.** Make it visually appealing and easy to read.
#
# Honestly, this CV needs a significant overhaul. Good luck.
#
#
# ================================================================================

# %% [markdown]
# ## Select Optimal Temperature
#
# Based on reading through the experiments above, we manually select the temperature that provides a good balance of:
# - Direct, honest feedback with critique points in candid tone
#
# **Recommended: 0.7 for medium roasting**

# %%
# Set optimal temperature
OPTIMAL_TEMPERATURE = 0.7

print(f" Selected optimal temperature: {OPTIMAL_TEMPERATURE}")
# Out:
#  Selected optimal temperature: 0.7

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# 1.  Direct CV critique prompt design
# 2.  Temperature tuning experiments (0.6, 0.7, 0.8)
# 3.  Selection of optimal temperature
# 4.  Generation of critiques
# 5.  Saving results for comparison
